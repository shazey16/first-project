# %%
import requests
import json
import csv
from bs4 import BeautifulSoup
from urllib.request import urlopen
from datetime import date

today = date.today()

import pandas as pd
import numpy as np
from pandas.tseries.offsets import DateOffset
pd.set_option('display.max_columns', 500)

# %%
from importlib import reload
import FPL
import utils
import const
reload(const)
reload(utils)
reload(FPL)

fpl_data = FPL.FPL()

# %%
fpl_data.team_data
# Out:
#               name  position  points  played  win  loss  draw  strength  \
# 0          Everton       1.5      13       6    4     1     0         4
# 1        Liverpool       1.5      13       6    4     1     0         5
# 2      Aston Villa       3.5      12       5    4     1     0         3
# 3        Leicester       3.5      12       6    4     2     0         4
# 4            Spurs       5.0      11       6    3     1     0         4
# 5            Leeds       7.5      10       6    3     2     0         3
# 6   Crystal Palace       7.5      10       6    3     2     0         3
# 7           Wolves       7.5      10       6    3     2     0         4
# 8      Southampton       7.5      10       6    3     2     0         3
# 9          Chelsea      10.5       9       6    2     1     0         4
# 10         Arsenal      10.5       9       6    3     3     0         4
# 11        West Ham      13.0       8       6    2     2     0         3
# ...

# %%
fpl_data.player_data[fpl_data.player_data['chance_of_playing_this_round'].isna()].sort_values(['position','value'],ascending=False).groupby('position').head(3)
# Out:
#                                        name    position         team  minutes  \
# 281  Hélder Wander Sousa de Azevedo e Costa  Midfielder        Leeds      487
# 274                           Mateusz Klich  Midfielder        Leeds      516
# 43                            Jack Grealish  Midfielder  Aston Villa      450
# 33                        Emiliano Martínez  Goalkeeper  Aston Villa      450
# 289                           Illan Meslier  Goalkeeper        Leeds      540
# 449                           Alex McCarthy  Goalkeeper  Southampton      540
# 278                         Patrick Bamford     Forward        Leeds      490
# 417                           Callum Wilson     Forward    Newcastle      534
# 478                              Harry Kane     Forward        Spurs      533
# 567                            Romain Saïss    Defender       Wolves      517
# 129                              Kurt Zouma    Defender      Chelsea      450
# ...

# %%
fpl_data.show_good_players(**filters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-835f878dfec1> in <module>
# ----> 1 fpl_data.show_good_players(**filters)
#
# NameError: name 'filters' is not defined

# %%
filters = {
    'value':0.2,
    'form':7,
    'minutes_per_game':45
}
a = pd.DataFrame(fpl_data.all_data['elements'])
a['name'] = a['first_name'] + ' ' + a['second_name']
a[a['name'].isin(list(fpl_data.show_good_players(**filters)['name'].unique()))]
# Out:
#      chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 43                            NaN                           NaN  114283
# 61                            NaN                           NaN  178301
# 129                           NaN                           NaN  103192
# 417                           NaN                           NaN   75115
# 478                           NaN                           NaN   78830
# 540                           NaN                           NaN   55459
# 567                           NaN                           NaN  107613
#
#      cost_change_event  cost_change_event_fall  cost_change_start  \
# 43                   1                      -1                  3
# 61                   0                       0                  0
# 129                  1                      -1                  1
# 417                  0                       0                  0
# ...

# %%
fpl_data.my_team_data
# Out:
#                                       name  position_y  substitute  \
# 0                          Jordan Pickford  Goalkeeper           0
# 1                               Willy Boly    Defender           0
# 2                              Reece James    Defender           0
# 3                             Tyrone Mings    Defender           0
# 4                       Kyle Walker-Peters    Defender           0
# 5   Hélder Wander Sousa de Azevedo e Costa  Midfielder           0
# 6                            Mohamed Salah  Midfielder           0
# 7                            Jack Grealish  Midfielder           0
# 8                        Donny van de Beek  Midfielder           0
# 9                          Michy Batshuayi     Forward           0
# 10                            Keinan Davis     Forward           0
# 11                   Alisson Ramses Becker  Goalkeeper           1
# 12                             Jamie Vardy     Forward           1
# ...
